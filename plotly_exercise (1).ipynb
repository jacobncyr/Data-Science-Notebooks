# %% [markdown]
# ## Plotly Assignment
#
# **Note**: For some of you, plotly go does not display at all in Jupyter Labs. It is a known bug with plotly. If you are using Jupyter Labs for this assignment and the plots are not showing, please switch to Jupyter Notebooks or Google Collab to complete this exercise.

# %%
# import plotly graph objects
import plotly.graph_objs as go

# import pandas
import pandas as pd

# %% [markdown]
# ### Task 1: Create a scatterplot with a 1000 random data points.
#
# - x-axis values should come from a normal distribution using np.random.randn(1000)
#
# - y-axis values should come from a uniform distribution over [0,1) using np.random.rand(1000)

# %%
# obtain the x and y values:
import numpy as np
random_x = np.random.randint(1,1001,1000)
random_y = np.random.randint(1,1001,1000)

# %%
# define a data variable
# create the data
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
)]

# %%
# define the layout, include a title and axis labels
# create the layout 
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# Create a fig from the data and layout. Then plot the fig
# create the figure
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="d03e5c9c-bc1d-4d50-981e-03b93e75e45b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d03e5c9c-bc1d-4d50-981e-03b93e75e45b")) {                    Plotly.newPlot(                        "d03e5c9c-bc1d-4d50-981e-03b93e75e45b",                        [{"mode":"markers","x":[807,189,604,626,254,250,108,5,985,655,309,100,505,804,590,947,307,574,443,230,29,314,905,549,428,302,413,289,374,697,267,182,627,896,374,831,884,113,307,38,125,107,329,757,233,361,135,948,302,143,520,383,280,115,561,670,346,256,785,882,488,574,209,573,106,119,423,384,788,255,830,1,211,425,107,414,960,481,958,678,341,206,172,640,852,633,485,72,712,194,848,131,147,684,389,139,937,892,549,816,980,170,467,768,284,127,271,867,234,293,183,103,594,831,545,186,425,885,576,692,773,860,755,513,912,399,640,714,886,465,902,454,610,593,964,596,823,723,87,334,299,673,783,287,910,71,455,381,47,256,226,551,271,871,656,268,683,233,676,545,16,204,139,753,335,103,345,257,524,823,131,975,312,190,533,406,208,842,586,606,571,226,854,53,529,971,46,149,138,434,674,223,734,583,416,431,620,786,850,442,921,669,834,852,510,844,133,813,936,845,709,567,142,403,654,452,261,276,527,701,952,950,707,277,966,226,139,597,919,345,735,81,824,652,737,344,425,962,659,599,262,958,703,743,25,669,123,95,979,792,615,58,843,495,87,332,427,46,985,900,177,860,600,33,354,772,491,345,324,183,546,71,860,632,220,898,549,736,476,319,273,649,299,164,946,567,849,357,375,623,853,840,7,331,299,992,624,615,172,746,902,332,285,91,147,949,635,129,339,4,59,305,290,355,46,361,55,480,809,174,298,519,323,955,651,724,265,721,327,591,934,785,864,934,887,965,215,192,474,174,473,485,472,812,247,589,269,542,383,741,493,189,585,820,865,907,285,647,113,483,381,688,255,505,83,644,768,315,977,468,216,594,340,600,983,168,75,804,361,364,903,990,665,838,28,267,204,161,754,374,513,910,630,844,31,980,680,37,64,482,145,501,930,629,71,726,618,85,67,145,239,257,565,114,853,941,504,111,108,738,872,118,847,672,204,487,449,8,914,339,989,898,146,963,656,364,878,790,397,615,941,864,259,88,841,185,738,171,350,720,809,694,876,475,178,800,229,461,764,283,111,263,771,868,838,960,567,657,353,600,846,329,10,160,887,154,197,455,972,577,458,589,576,458,140,439,826,363,746,96,908,996,374,621,895,105,294,305,288,628,458,868,475,679,198,457,654,157,217,507,427,611,96,589,740,699,792,699,267,790,953,227,213,59,385,829,106,836,324,831,301,388,615,876,370,167,713,984,137,567,772,40,925,568,707,365,932,48,553,263,915,888,675,457,972,227,952,583,775,217,559,296,954,354,905,183,60,940,982,936,102,203,316,335,494,87,111,648,555,149,527,828,519,915,90,895,75,804,640,898,949,623,617,581,521,467,752,551,389,539,161,286,335,105,704,68,315,961,57,344,76,503,947,526,868,978,710,120,564,92,574,881,520,444,274,306,935,268,867,209,904,637,198,683,21,879,94,979,994,733,88,686,490,101,853,483,133,53,233,936,273,420,821,980,253,93,152,648,515,521,972,134,920,165,321,155,431,723,548,374,256,664,272,982,444,668,177,80,576,93,444,412,880,143,590,980,564,669,890,999,712,161,649,953,874,281,319,600,571,181,541,793,663,303,994,910,80,860,78,479,542,584,514,58,177,624,196,447,769,792,448,856,201,11,70,439,114,326,361,101,167,184,758,367,901,864,766,196,389,771,913,790,78,430,791,892,231,138,692,637,314,860,409,725,524,298,757,707,310,74,984,143,270,159,964,172,141,404,122,811,100,367,543,24,126,1000,492,783,818,19,158,899,832,164,211,876,621,587,22,154,247,928,376,200,950,100,511,604,768,327,337,699,466,857,541,481,740,823,422,253,240,513,426,791,218,310,508,577,900,584,900,297,462,841,483,924,55,163,568,711,397,374,137,445,524,855,605,388,812,438,337,487,891,972,77,14,520,445,336,845,845,802,53,210,538,711,927,882,107,59,696,914,211,712,264,470,479,708,497,32,437,459,28,222,137,85,609,11,14,861,607,628 ...

# %% [markdown]
# -------------
# ### Task 2: Create a stacked bar chart with the data from the link below.
#
# **Note** that the questions appear in the index and should be used for the x-axis, while the responses appear as column labels. You will need to create more `traces`, one for each column.
#
# Stretch Task: Create a horizontal bar chart! Use this documentation [here](https://plot.ly/python/horizontal-bar-charts/) for help.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/mocksurvey.csv',index_col=0)

# %%
# create traces using a list comprehension:
import plotly.graph_objects as go

# Get the questions from the DataFrame index
questions = df.index.tolist()

# Get the responses from the DataFrame columns
responses = df.columns.tolist()

# Get the data values from the DataFrame
data = df.values.tolist()

# Create a trace for each response
traces = []
for i in range(len(responses)):
    trace = go.Bar(
        x=questions,
        y=[row[i] for row in data],
        name=responses[i]
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Responses to Questions',
    barmode='stack'  # Stack the bars
)

# Create the figure and plot
fig = go.Figure(data=traces, layout=layout)
fig.show()
# Out:
# <div>                            <div id="d2aeec2e-3c70-4989-9f81-74b52a471cf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2aeec2e-3c70-4989-9f81-74b52a471cf7")) {                    Plotly.newPlot(                        "d2aeec2e-3c70-4989-9f81-74b52a471cf7",                        [{"name":"Strongly Agree","x":["Question 1","Question 2","Question 3"],"y":[0.45,0.12,0.05],"type":"bar"},{"name":"Somewhat Agree","x":["Question 1","Question 2","Question 3"],"y":[0.25,0.07,0.22],"type":"bar"},{"name":"Neutral","x":["Question 1","Question 2","Question 3"],"y":[0.1,0.48,0.19],"type":"bar"},{"name":"Somewhat Disagree","x":["Question 1","Question 2","Question 3"],"y":[0.12,0.18,0.23],"type":"bar"},{"name":"Strongly Disagree","x":["Question 1","Question 2","Question 3"],"y":[0.08,0.15,0.31],"type":"bar"}],                        {"barmode":"stack","title":{"text":"Responses to Questions"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E ...

# %%
# create a layout, remember to set the barmode here

# %%
# create a fig from data & layout, and plot the fig.

# %% [markdown]
# -------------
# ### Task 3: Create a histogram that plots the `length` field from dataset below. Set the range from 0 to 1, with a bin size of 0.02.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/abalone.csv')

# %%
# create a data variable:
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame called 'df'
length_data = df['length']

# Set the range and bin size
bin_size = 0.02
bins = [i * bin_size for i in range(int(1 / bin_size) + 1)]

# Create the histogram
plt.hist(length_data, bins=bins, range=(0, 1))

# Set the labels and title
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('Histogram of Length')

# Display the histogram
plt.show()

# %%
# add a layout

# %%
# create a fig from data & layout, and plot the fig
